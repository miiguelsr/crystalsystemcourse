# %% [markdown]
# # Data Preparation
#
# Miguel Alejandro Salas Reyna (2022), Data Science and Mathematics Student.
#
# Instituto Tecnológico y de Estudios Superiores de Monterrey (ITESM).

# %%
# libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date
import numpy as np

# %%
df = pd.read_csv("Automotive_2.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171528 entries, 0 to 171527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          171528 non-null  object
#  1   name                 171528 non-null  object
#  2   seller               171528 non-null  object
#  3   offerType            171528 non-null  object
#  4   price                171528 non-null  object
#  5   abtest               171516 non-null  object
#  6   vehicleType          154049 non-null  object
#  7   yearOfRegistration   171518 non-null  object
#  8   gearbox              162178 non-null  object
#  9   powerPS              171524 non-null  object
#  10  model                162165 non-null  object
#  11  kilometer            171528 non-null  int64
#  12  monthOfRegistration  171512 non-null  object
#  13  fuelType             156241 non-null  object
#  14  brand                171486 non-null  object
# ...

# %%
df.head(10)
# Out:
#        dateCrawled                                               name  seller  \
# 0  3/26/2016 14:57  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...  privat
# 1  3/23/2016 20:57                   Renault_clio_mit_nagelneuen_T?!*  privat
# 2  3/19/2016 18:56                              VW_LUPO._1.1l_T?_3/18  privat
# 3  3/30/2016 12:51             Opel_Astra_Caravan_Sport_sehr_gepflegt  privat
# 4  3/26/2016 21:36              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend  privat
# 5  3/15/2016 19:45                   Audi_Q5_3.0_TDI_quattro_S_tronic  privat
# 6   3/7/2016 22:48                                     Alfa_Romeo_147  privat
# 7  3/30/2016 20:57                            renaut_espace_fast_frei  privat
# 8   4/2/2016 10:56                    BMW_e36_316i_Compact_1_9_T?_neu  privat
# 9   4/1/2016 12:53       Renault_Trafic_2.5_dCi_Generation_Expression  privat
#
#   offerType  price   abtest vehicleType yearOfRegistration    gearbox powerPS  \
# ...

# %%
df.shape
# Out:
# (171528, 20)

# %%
df['notRepairedDamage'] = df['notRepairedDamage'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171528 entries, 0 to 171527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          171528 non-null  object
#  1   name                 171528 non-null  object
#  2   seller               171528 non-null  object
#  3   offerType            171528 non-null  object
#  4   price                171528 non-null  object
#  5   abtest               171516 non-null  object
#  6   vehicleType          154049 non-null  object
#  7   yearOfRegistration   171518 non-null  object
#  8   gearbox              162178 non-null  object
#  9   powerPS              171524 non-null  object
#  10  model                162165 non-null  object
#  11  kilometer            171528 non-null  int64
#  12  monthOfRegistration  171512 non-null  object
#  13  fuelType             156241 non-null  object
#  14  brand                171486 non-null  object
# ...

# %%
null=df[df['lastSeen'].isnull()]
null
# Out:
#             dateCrawled                                               name  \
# 687     3/22/2016 12:58                                   Audi_Coup?privat
# 2022    3/22/2016 22:51                                   325i_Coup?privat
# 2135     3/9/2016 13:52                        ??ord_Galaxy_T?_NEU??privat
# 2522    3/25/2016 14:45                            MINI_Cooper_Coup?privat
# 3115    3/24/2016 18:51         Verkaufe_oder_tausche_E36_316i_Coup?privat
# ...                 ...                                                ...
# 167476  3/20/2016 17:54            ??MERCEDES_C_KLASSE_180_MIT_T?_??privat
# 168242  3/30/2016 23:44                               FIAT_500_Coup?privat
# 168256   4/5/2016 10:55  Liebhaberauto_Peugeot_406_Coupe_mit_LPG_6_Zyli...
# 169333   3/8/2016 17:56                          MINI_Cooper_S_Coup?privat
# 171342    4/1/2016 1:56                              Suche_e46_Coup?privat
#
# ...

# %%
#Drop of null values
df=df.dropna()

# %%
df
# Out:
#             dateCrawled                                               name  \
# 0       3/26/2016 14:57  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...
# 1       3/23/2016 20:57                   Renault_clio_mit_nagelneuen_T?!*
# 2       3/19/2016 18:56                              VW_LUPO._1.1l_T?_3/18
# 3       3/30/2016 12:51             Opel_Astra_Caravan_Sport_sehr_gepflegt
# 4       3/26/2016 21:36              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend
# ...                 ...                                                ...
# 171521  3/27/2016 20:36                  Opel_Zafira_1.6_Elegance_T?_12/16
# 171524   3/5/2016 19:56              Smart_smart_leistungssteigerung_100ps
# 171525  3/19/2016 18:57                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 171526  3/20/2016 19:41                             VW_Golf_Kombi_1_9l_TDI
# 171527   3/7/2016 19:39       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138344 entries, 0 to 171527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          138344 non-null  object
#  1   name                 138344 non-null  object
#  2   seller               138344 non-null  object
#  3   offerType            138344 non-null  object
#  4   price                138344 non-null  object
#  5   abtest               138344 non-null  object
#  6   vehicleType          138344 non-null  object
#  7   yearOfRegistration   138344 non-null  object
#  8   gearbox              138344 non-null  object
#  9   powerPS              138344 non-null  object
#  10  model                138344 non-null  object
#  11  kilometer            138344 non-null  int64
#  12  monthOfRegistration  138344 non-null  object
#  13  fuelType             138344 non-null  object
#  14  brand                138344 non-null  object
# ...

# %%
df['notRepairedDamage'] = df['notRepairedDamage'].replace("no", 0)

# %%
df['notRepairedDamage'] = df['notRepairedDamage'].replace("yes", 1)

# %%
df["notRepairedDamage"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df["seller"].unique()
# Out:
# array(['privat'], dtype=object)

# %%
df["offerType"].unique()
# Out:
# array(['Angebot', 'Gesuch'], dtype=object)

# %%
columns = df.columns
list(columns)
# Out:
# ['dateCrawled',
#  'name',
#  'seller',
#  'offerType',
#  'price',
#  'abtest',
#  'vehicleType',
#  'yearOfRegistration',
#  'gearbox',
#  'powerPS',
#  'model',
#  'kilometer',
#  'monthOfRegistration',
#  'fuelType',
#  'brand',
#  'notRepairedDamage',
#  'dateCreated',
#  'nrOfPictures',
#  'postalCode',
#  'lastSeen']

# %%
for col in df:
    print(col + " ")
    print(df[col].unique())
# Out:
# dateCrawled
# ['3/26/2016 14:57' '3/23/2016 20:57' '3/19/2016 18:56' ... '3/8/2016 0:49'
#  '3/26/2016 8:52' '3/6/2016 21:11']
# name
# ['BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Klima_MFL'
#  'Renault_clio_mit_nagelneuen_T?!*' 'VW_LUPO._1.1l_T?_3/18' ...
#  'Smart_smart_leistungssteigerung_100ps' 'VW_Golf_Kombi_1_9l_TDI'
#  'BMW_M135i_vollausgestattet_NP_52.720____Euro']
# seller
# ['privat']
# offerType
# ['Angebot' 'Gesuch']
# price
# ['10499' '1199' '2750' ... '10985' '14989' '15190']
# abtest
# ['control' 'test']
# vehicleType
# ['limousine' 'kleinwagen' 'kombi' 'suv' 'bus' 'cabrio' 'coupe' 'andere']
# yearOfRegistration
# ['2006' '2001' '1999' '2004' '2012' '2002' '1998' '2005' '2011' '2007'
#  '2003' '2008' '2013' '2009' '1994' '2010' '2000' '1993' '2016' '1992'
#  '1980' '2014' '1997' '1995' '1988' '1991' '1996' '1984' '1989' '2015'
#  '1990' '1987' '1978' '1985' '1966' '1981' '1965' '1970' '1968' '1986'
# ...

# %%
df['dateCrawled'] =  pd.to_datetime(df['dateCrawled'])
df['dateCreated'] =  pd.to_datetime(df['dateCreated'])
df['lastSeen'] =  pd.to_datetime(df['lastSeen'])

# %%
df['days'] = (df['lastSeen'] - df['dateCrawled']).dt.days

# %%
df = df.drop_duplicates()

# %%
df.describe()
# Out:
#            kilometer  notRepairedDamage  nrOfPictures           days
# count  138330.000000      138330.000000      138330.0  138330.000000
# mean   125400.093978           0.093949           0.0       8.347618
# std     39290.017236           0.291759           0.0       8.334088
# min      5000.000000           0.000000           0.0       0.000000
# 25%    100000.000000           0.000000           0.0       2.000000
# 50%    150000.000000           0.000000           0.0       5.000000
# 75%    150000.000000           0.000000           0.0      13.000000
# max    150000.000000           1.000000           0.0      33.000000

# %%
df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 14:57:00  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...
# 1      2016-03-23 20:57:00                   Renault_clio_mit_nagelneuen_T?!*
# 2      2016-03-19 18:56:00                              VW_LUPO._1.1l_T?_3/18
# 3      2016-03-30 12:51:00             Opel_Astra_Caravan_Sport_sehr_gepflegt
# 4      2016-03-26 21:36:00              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend
# ...                    ...                                                ...
# 171521 2016-03-27 20:36:00                  Opel_Zafira_1.6_Elegance_T?_12/16
# 171524 2016-03-05 19:56:00              Smart_smart_leistungssteigerung_100ps
# 171525 2016-03-19 18:57:00                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 171526 2016-03-20 19:41:00                             VW_Golf_Kombi_1_9l_TDI
# 171527 2016-03-07 19:39:00       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
plt.title('days')
plt.boxplot(df.days)
plt.show()

# %%
df['days'].hist(bins=30, figsize=[14,6])
# Out:
# <AxesSubplot:>

# %%
df['status'] = np.where(df['days']== 0, 1, 0)
# Out:
# C:\Users\miigu\AppData\Local\Temp/ipykernel_3788/1346384139.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['status'] = np.where(df['days']== 0, 1, 0)

# %%
df.loc[df['days'] == 0]
# Out:
#                dateCrawled                                               name  \
# 12     2016-03-19 20:51:00                         Toyota_Yaris_Verso_1.3_Sol
# 17     2016-03-30 00:46:00                    Volkswagen_Polo_1.2_Comfortline
# 22     2016-03-12 10:55:00  Passat_2.0_TDI_140_PS_140ooo_km_Tempomat_Sitzh...
# 41     2016-03-26 10:48:00                                Polo_United_1.4_TDI
# 49     2016-04-04 16:50:00      Zafira_Tourer_2.0_CDTI_Start_Stop_Navi_Kamera
# ...                    ...                                                ...
# 171454 2016-03-12 17:59:00  Audi_A_6_S_line_.kombi__6_Gang.2_5__Diesel_.__...
# 171465 2016-03-10 11:51:00                                       Vito_108_CDI
# 171466 2016-03-08 20:43:00     GOLF_V_1.9_TDI_GT_SPORT_BI_XENON__NAVI_DVD_ROT
# 171471 2016-03-07 19:58:00                 Trabant_P70_Coupe_Oldtimer_IFA_DDR
# 171520 2016-03-19 19:53:00                                       turbo_defekt
#
# ...

# %%
df = df.drop(columns=['seller', 'nrOfPictures'])

# %%
df["price"] = pd.to_numeric(df["price"])
df["yearOfRegistration"] = pd.to_numeric(df["yearOfRegistration"])
df["powerPS"] = pd.to_numeric(df["powerPS"])
df["kilometer"] = pd.to_numeric(df["kilometer"])
df["monthOfRegistration"] = pd.to_numeric(df["monthOfRegistration"])

# %%
df.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  1.383300e+05       138330.000000  138330.000000  138330.000000
# mean   8.083142e+03         2002.926863     123.526039  125400.093978
# std    3.843694e+05            6.550282     173.810988   39290.017236
# min    0.000000e+00         1910.000000       0.000000    5000.000000
# 25%    1.399000e+03         1999.000000      75.000000  100000.000000
# 50%    3.499000e+03         2003.000000     115.000000  150000.000000
# 75%    7.999000e+03         2007.000000     150.000000  150000.000000
# max    1.000000e+08         2018.000000   20000.000000  150000.000000
#
#        monthOfRegistration  notRepairedDamage           days         status
# count        138330.000000      138330.000000  138330.000000  138330.000000
# mean              6.082419           0.093949       8.347618       0.170375
# std               3.536244           0.291759       8.334088       0.375963
# ...

# %%
print(df.groupby(['model']).count())
# Out:
#          dateCrawled  name  offerType  price  abtest  vehicleType  \
# model
# 100              178   178        178    178     178          178
# 145               16    16         16     16      16           16
# 147              225   225        225    225     225          225
# 156              239   239        239    239     239          239
# 159               91    91         91     91      91           91
# ...              ...   ...        ...    ...     ...          ...
# yaris            436   436        436    436     436          436
# yeti              96    96         96     96      96           96
# ypsilon           79    79         79     79      79           79
# z_reihe          385   385        385    385     385          385
# zafira          1153  1153       1153   1153    1153         1153
#
#          yearOfRegistration  gearbox  powerPS  kilometer  monthOfRegistration  \
# model
# 100                     178      178      178        178                  178
# ...

# %%
car_models = df.model.value_counts()

# %%
car_models = pd.DataFrame(car_models)

# %%
car_models
# Out:
#                  model
# golf             11341
# andere           10559
# 3er               8360
# polo              4865
# corsa             4639
# ...                ...
# serie_3              2
# samara               2
# serie_2              2
# serie_1              1
# discovery_sport      1
#
# [250 rows x 1 columns]

# %%
car_models.loc[car_models['model'] > 1000]
# Out:
#              model
# golf         11341
# andere       10559
# 3er           8360
# polo          4865
# corsa         4639
# a4            4202
# astra         4148
# passat        4052
# 5er           3666
# c_klasse      3654
# e_klasse      3144
# a6            2518
# a3            2517
# focus         2362
# transporter   2253
# fiesta        2185
# 2_reihe       1980
# twingo        1738
# a_klasse      1609
# 1er           1576
# vectra        1570
# fortwo        1505
# mondeo        1472
# 3_reihe       1383
# touran        1367
# clio          1306
# punto         1201
# zafira        1153
# megane        1131
# lupo          1021
# ibiza         1018
# ka            1002

# %%
car_models.loc[(car_models['model'] >= 75) & (car_models['model'] <= 1000)]
# Out:
#           model
# x_reihe     989
# octavia     910
# cooper      895
# fabia       872
# clk         816
# ...         ...
# ypsilon      79
# jimny        79
# cc           78
# lancer       77
# g_klasse     76
#
# [155 rows x 1 columns]

# %%
df = df[df.powerPS >= 50]

# %%
df.describe()
# Out:
#               price  yearOfRegistration        powerPS      kilometer  \
# count  1.289660e+05       128966.000000  128966.000000  128966.000000
# mean   7.599813e+03         2003.255641     131.896857  125115.922026
# std    2.828041e+05            6.247818     177.054593   39289.463954
# min    0.000000e+00         1934.000000      50.000000    5000.000000
# 25%    1.500000e+03         1999.000000      86.000000  100000.000000
# 50%    3.700000e+03         2004.000000     116.000000  150000.000000
# 75%    8.450000e+03         2008.000000     155.000000  150000.000000
# max    9.900000e+07         2018.000000   20000.000000  150000.000000
#
#        monthOfRegistration  notRepairedDamage           days         status
# count        128966.000000      128966.000000  128966.000000  128966.000000
# mean              6.134725           0.090264       8.421328       0.166974
# std               3.502043           0.286561       8.350384       0.372954
# ...

# %%
df.loc[df['powerPS'] >= 1000]
# Out:
#                dateCrawled                                               name  \
# 514    2016-03-28 12:47:00                                        opel_vectra
# 4576   2016-03-18 15:42:00                                 Golf_2._CL_Bj_1989
# 5785   2016-03-05 16:53:00       A140__Als_Bastler_Fahrzeug_nicht_fahrbereit_
# 6116   2016-03-20 16:51:00                           Verkaufe_meinen_bmw_525d
# 7551   2016-03-11 13:58:00                            Audi_A4_Quatrro_1.9_TDI
# ...                    ...                                                ...
# 165025 2016-03-16 21:48:00                                    Golf_3/3_Tueren
# 165133 2016-04-04 12:38:00                                Opel_Corsa_1.7_cdti
# 165806 2016-03-13 11:51:00                   Top_gepflegter_Scenic_von_Privat
# 165894 2016-04-04 18:53:00                                    Baster_Fahrzeug
# 169007 2016-03-07 21:36:00  !!!!!_Opel_zafira_2.0_dti_16_v_comfort_verkauf...
#
# ...

# %%
df.loc[df['price'] >= 5000]
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 14:57:00  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...
# 4      2016-03-26 21:36:00              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend
# 5      2016-03-15 19:45:00                   Audi_Q5_3.0_TDI_quattro_S_tronic
# 9      2016-04-01 12:53:00       Renault_Trafic_2.5_dCi_Generation_Expression
# 10     2016-03-20 20:56:00                               BMW_Z4_roadster_2.2i
# ...                    ...                                                ...
# 171510 2016-03-06 21:11:00  Mercedes_benz_e_klasse_avangarde_220_cdi_grune...
# 171512 2016-03-25 18:48:00                 Mercedes_Benz_E_400_CDI_Avantgarde
# 171517 2016-03-28 13:48:00                   Volkswagen_Golf_2.0_TDI_DPF_Team
# 171525 2016-03-19 18:57:00                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 171527 2016-03-07 19:39:00       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
df.loc[(df['price'] >= 20000) & (df['status'] == 0)]
# Out:
#                dateCrawled                                               name  \
# 5      2016-03-15 19:45:00                   Audi_Q5_3.0_TDI_quattro_S_tronic
# 24     2016-03-15 21:50:00          Audi_A5_2.0_TDI_Sportback_DPF_multitronic
# 46     2016-03-19 11:56:00  Porsche_Cayenne_Diesel_SportDesign_21"_Luft_1....
# 53     2016-03-17 14:47:00    CLA_180_Urban_NEUWAGEN!_20_km_"Neupreis_30800?"
# 65     2016-03-10 12:50:00                    Audi_A6_Avant_2.0_TDI_Ultra_DPF
# ...                    ...                                                ...
# 171435 2016-03-31 23:40:00                                BMW_525d_Sport_Aut.
# 171477 2016-03-07 16:50:00                        BMW_525d_Touring_Sport_Aut.
# 171483 2016-03-07 09:54:00  Mercedes_Benz_E_200_CDI_DPF_BlueEFFICIENCY_7G_...
# 171500 2016-03-21 23:40:00  Volkswagen_Golf_1.4_TSI_BlueMotion_Technology_...
# 171527 2016-03-07 19:39:00       BMW_M135i_vollausgestattet_NP_52.720____Euro
#
# ...

# %%
plt.title('PowerPS')
plt.boxplot(df.powerPS)
plt.show()

# %%
plt.title('price')
plt.boxplot(df.price)
plt.show()

# %%
plt.title('yearOfRegistration')
plt.boxplot(df.yearOfRegistration)
plt.show()

# %%
cols = ['powerPS', 'price', 'yearOfRegistration']

Q1 = df[cols].quantile(0.25)
Q3 = df[cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[cols] < (Q1 - 1.5 * IQR)) |(df[cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
plt.title('PowerPS')
plt.boxplot(df.powerPS)
plt.show()

# %%
plt.title('price')
plt.boxplot(df.price)
plt.show()

# %%
plt.title('yearOfRegistration')
plt.boxplot(df.yearOfRegistration)
plt.show()

# %%
df.loc[df['price'] >= 5000]
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 14:57:00  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...
# 4      2016-03-26 21:36:00              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend
# 9      2016-04-01 12:53:00       Renault_Trafic_2.5_dCi_Generation_Expression
# 10     2016-03-20 20:56:00                               BMW_Z4_roadster_2.2i
# 11     2016-03-16 13:50:00  Ford_C_max_1_6_EcoBost_Titanium_Start_Stop_Top...
# ...                    ...                                                ...
# 171506 2016-03-20 18:47:00  Volkswagen_Golf_1.9_TDI_DPF_Goal_Rentnerfzg._1...
# 171507 2016-03-16 17:06:00  Gepflegter_Audi_a4_2.0tdi_xenon_ahk_klima_sche...
# 171510 2016-03-06 21:11:00  Mercedes_benz_e_klasse_avangarde_220_cdi_grune...
# 171517 2016-03-28 13:48:00                   Volkswagen_Golf_2.0_TDI_DPF_Team
# 171525 2016-03-19 18:57:00                 Volkswagen_Multivan_T4_TDI_7DC_UY2
#
# ...

# %%
df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 14:57:00  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...
# 2      2016-03-19 18:56:00                              VW_LUPO._1.1l_T?_3/18
# 3      2016-03-30 12:51:00             Opel_Astra_Caravan_Sport_sehr_gepflegt
# 4      2016-03-26 21:36:00              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend
# 6      2016-03-07 22:48:00                                     Alfa_Romeo_147
# ...                    ...                                                ...
# 171517 2016-03-28 13:48:00                   Volkswagen_Golf_2.0_TDI_DPF_Team
# 171520 2016-03-19 19:53:00                                       turbo_defekt
# 171524 2016-03-05 19:56:00              Smart_smart_leistungssteigerung_100ps
# 171525 2016-03-19 18:57:00                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 171526 2016-03-20 19:41:00                             VW_Golf_Kombi_1_9l_TDI
#
# ...

# %%
df.name.value_counts()
# Out:
# BMW_318i                                                        296
# Volkswagen_Golf_1.4                                             261
# BMW_320i                                                        229
# BMW_316i                                                        228
# Ford_Fiesta                                                     198
#                                                                ...
# Peugeot_307_CC_140_JBL_Cabrio                                     1
# BMW_X5_3.0_d_Gelegenheit!_Vollausstattung___wenig_Kilometer!      1
# Peugeot_206cc_T?_07_2016                                          1
# VW_Golf_2_GT_G60_Renner__Slalom__Viertel_Meile                    1
# VW_Golf_Kombi_1_9l_TDI                                            1
# Name: name, Length: 75522, dtype: int64

# %%
df.describe()
# Out:
#                price  yearOfRegistration        powerPS      kilometer  \
# count  116931.000000       116931.000000  116931.000000  116931.000000
# mean     4728.572620         2003.035577     118.587817  128653.949765
# std      4333.565384            5.359477      44.888983   36147.280310
# min         0.000000         1986.000000      50.000000    5000.000000
# 25%      1399.000000         1999.000000      80.000000  125000.000000
# 50%      3200.000000         2003.000000     114.000000  150000.000000
# 75%      6900.000000         2007.000000     147.000000  150000.000000
# max     18850.000000         2018.000000     258.000000  150000.000000
#
#        monthOfRegistration  notRepairedDamage           days         status
# count        116931.000000      116931.000000  116931.000000  116931.000000
# mean              6.132078           0.095817       8.199861       0.174009
# std               3.512960           0.294342       8.272787       0.379119
# ...

# %%
df.loc[df['yearOfRegistration'] <= 1990]
# Out:
#                dateCrawled                                               name  \
# 307    2016-04-04 02:36:00                                    Audi_80_T?_2017
# 377    2016-03-21 02:36:00                     BMW_535i_e34_mit_vielen_Extras
# 489    2016-04-01 20:57:00  Audi_100_quattro__2.3__Tuev_09_2017__Anhaenger...
# 520    2016-03-16 14:54:00                               Mercedes_Benz_CE_300
# 603    2016-03-12 19:00:00     Volkswagen_Golf_2_Rat_style_T?_NEU_top_zustand
# ...                    ...                                                ...
# 171376 2016-03-05 21:57:00            Volkswagen_Golf_2_VR6_alles_Eingetragen
# 171391 2016-03-17 13:38:00                                           BMW_730i
# 171439 2016-04-05 07:37:00     Volkswagen_T3_DoKa_Pritsche_Transporter_1_6_TD
# 171459 2016-03-05 16:44:00                                    Audi_80_quattro
# 171468 2016-04-04 19:45:00                                         VW_Golf_II
#
# ...

# %%
for col in df:
    print(col + " ")
    print(df[col].unique())
# Out:
# dateCrawled
# ['2016-03-26T14:57:00.000000000' '2016-03-19T18:56:00.000000000'
#  '2016-03-30T12:51:00.000000000' ... '2016-03-26T08:52:00.000000000'
#  '2016-04-05T07:37:00.000000000' '2016-03-06T21:11:00.000000000']
# name
# ['BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Klima_MFL'
#  'VW_LUPO._1.1l_T?_3/18' 'Opel_Astra_Caravan_Sport_sehr_gepflegt' ...
#  'turbo_defekt' 'Smart_smart_leistungssteigerung_100ps'
#  'VW_Golf_Kombi_1_9l_TDI']
# offerType
# ['Angebot' 'Gesuch']
# price
# [10499  2750  3500 ... 10985 14989 15190]
# abtest
# ['control' 'test']
# vehicleType
# ['limousine' 'kleinwagen' 'kombi' 'bus' 'cabrio' 'coupe' 'andere' 'suv']
# yearOfRegistration
# [2006 1999 2004 2012 2002 1998 2005 2011 2001 2007 2003 2008 2013 2009
#  1994 2010 2000 1993 1997 2014 1995 1991 1992 1996 1989 1990 1987 1988
#  1986 2016 2015 2017 2018]
# gearbox
# ['manual' 'automatik']
# powerPS
# [163  50 125 116 105 115 135 170 182  86 140 232  64 136 126  95 165 109
# ...

# %%
df.describe()
# Out:
#                price  yearOfRegistration        powerPS      kilometer  \
# count  116931.000000       116931.000000  116931.000000  116931.000000
# mean     4728.572620         2003.035577     118.587817  128653.949765
# std      4333.565384            5.359477      44.888983   36147.280310
# min         0.000000         1986.000000      50.000000    5000.000000
# 25%      1399.000000         1999.000000      80.000000  125000.000000
# 50%      3200.000000         2003.000000     114.000000  150000.000000
# 75%      6900.000000         2007.000000     147.000000  150000.000000
# max     18850.000000         2018.000000     258.000000  150000.000000
#
#        monthOfRegistration  notRepairedDamage           days         status
# count        116931.000000      116931.000000  116931.000000  116931.000000
# mean              6.132078           0.095817       8.199861       0.174009
# std               3.512960           0.294342       8.272787       0.379119
# ...

# %%
df
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 14:57:00  BMW_320d_DPFXenon_Tempomat_Sitzheizung_PDC_Kli...
# 2      2016-03-19 18:56:00                              VW_LUPO._1.1l_T?_3/18
# 3      2016-03-30 12:51:00             Opel_Astra_Caravan_Sport_sehr_gepflegt
# 4      2016-03-26 21:36:00              Ford_Focus_Turnier_1.6_TDCi_DPF_Trend
# 6      2016-03-07 22:48:00                                     Alfa_Romeo_147
# ...                    ...                                                ...
# 171517 2016-03-28 13:48:00                   Volkswagen_Golf_2.0_TDI_DPF_Team
# 171520 2016-03-19 19:53:00                                       turbo_defekt
# 171524 2016-03-05 19:56:00              Smart_smart_leistungssteigerung_100ps
# 171525 2016-03-19 18:57:00                 Volkswagen_Multivan_T4_TDI_7DC_UY2
# 171526 2016-03-20 19:41:00                             VW_Golf_Kombi_1_9l_TDI
#
# ...

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.drop(colgenres = np.unique(vg_df['Genre'])
genresumns=['dateCrawled', 'dateCreated', 'lastSeen', 'lastSeen', 'name', 'days', 'postalCode'])

# %%
df_copy
# Out:
#        offerType  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0        Angebot  10499  control   limousine                2006     manual
# 2        Angebot   2750     test  kleinwagen                1999     manual
# 3        Angebot   3500  control       kombi                2004     manual
# 4        Angebot   7500  control       kombi                2012     manual
# 6        Angebot   1050     test  kleinwagen                2002     manual
# ...          ...    ...      ...         ...                 ...        ...
# 171517   Angebot   7900     test   limousine                2010     manual
# 171520   Angebot   3200  control   limousine                2004     manual
# 171524   Angebot   1199     test      cabrio                2000  automatik
# 171525   Angebot   9200     test         bus                1996     manual
# 171526   Angebot   3400     test       kombi                2002     manual
#
# ...

# %%
car_models_df_copy = df_copy.model.value_counts()

# %%
car_models_df_copy = pd.DataFrame(car_models_df_copy)

# %%
car_models_df_copy
# Out:
#             model
# golf        10301
# andere       7605
# 3er          7425
# polo         4141
# astra        3858
# ...           ...
# i3              2
# samara          2
# elefantino      2
# 911             1
# kaefer          1
#
# [244 rows x 1 columns]

# %%
df["postalCode"] = pd.to_numeric(df["postalCode"])

# %%
df.describe()
# Out:
#                price  yearOfRegistration        powerPS      kilometer  \
# count  116931.000000       116931.000000  116931.000000  116931.000000
# mean     4728.572620         2003.035577     118.587817  128653.949765
# std      4333.565384            5.359477      44.888983   36147.280310
# min         0.000000         1986.000000      50.000000    5000.000000
# 25%      1399.000000         1999.000000      80.000000  125000.000000
# 50%      3200.000000         2003.000000     114.000000  150000.000000
# 75%      6900.000000         2007.000000     147.000000  150000.000000
# max     18850.000000         2018.000000     258.000000  150000.000000
#
#        monthOfRegistration  notRepairedDamage     postalCode           days  \
# count        116931.000000      116931.000000  116931.000000  116931.000000
# mean              6.132078           0.095817   51496.385954       8.199861
# std               3.512960           0.294342   25784.118869       8.272787
# ...

# %%
plt.title('postalCode')
plt.boxplot(df.postalCode)
plt.show()

# %%
#df_copy.to_csv('Automotive_2_clean_data.csv', index = False)

# %%
df_copy
# Out:
#        offerType  price   abtest vehicleType  yearOfRegistration    gearbox  \
# 0        Angebot  10499  control   limousine                2006     manual
# 2        Angebot   2750     test  kleinwagen                1999     manual
# 3        Angebot   3500  control       kombi                2004     manual
# 4        Angebot   7500  control       kombi                2012     manual
# 6        Angebot   1050     test  kleinwagen                2002     manual
# ...          ...    ...      ...         ...                 ...        ...
# 171517   Angebot   7900     test   limousine                2010     manual
# 171520   Angebot   3200  control   limousine                2004     manual
# 171524   Angebot   1199     test      cabrio                2000  automatik
# 171525   Angebot   9200     test         bus                1996     manual
# 171526   Angebot   3400     test       kombi                2002     manual
#
# ...
